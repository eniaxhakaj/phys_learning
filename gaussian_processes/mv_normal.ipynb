# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Uncorrelated MV normal dist
data = np.random.multivariate_normal(
        np.array([0, 1]),
        np.array([
            [3, 0],
            [0, 1],
        ]),
        size = 500,
)

# Together they are MV normal
_, ax = plt.subplots()
ax.scatter(data[:,0], data[:,1])
ax.set(ylim=(-5, 5), xlim=(-5, 5))

# Each axis indepedently is normally distributed
_, axes = plt.subplots(2)
for i in range(2):
    axes[i].hist(data[:,i])
    axes[i].set(xlim=(-5, 5))

# %%
# Correlated MV normal dist
max_cov = np.sqrt(2) * np.sqrt(3)
data = np.random.multivariate_normal(
        np.array([0, 1]),
        np.array([
            [2, max_cov],
            [max_cov, 3],
        ]),
        size = 1500,
)

# Together they are MV normal
_, ax = plt.subplots()
ax.scatter(data[:,0], data[:,1])
ax.set(ylim=(-5, 5), xlim=(-5, 5))

# Each axis indepedently is normally distributed
_, axes = plt.subplots(2)
for i in range(2):
    axes[i].hist(data[:,i], bins=30)
    axes[i].set(xlim=(-5, 5))

# %%
a = np.random.normal(0, 2, 1000) # Standard dev of 2, var of 4
b = a*2 # Standard dev of 4, var of 16

cov = np.cov(a, b)

mv_draw = np.random.multivariate_normal(np.array([0, 0]), cov, size = 1000)

# Together they are MV normal
_, ax = plt.subplots()
ax.scatter(mv_draw[:,0], mv_draw[:,1])
ax.set(ylim=(-12, 12), xlim=(-12, 12))

ax.scatter(a, b-2, c="red")
